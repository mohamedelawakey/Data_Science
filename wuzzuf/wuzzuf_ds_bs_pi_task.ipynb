# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

# %%
search_list = ["Machine Learning Engineer", "Data Analyst", "Data Scientist", "Business Intelligence"]
base_url = "https://wuzzuf.net/search/jobs/?q={}&a=hpb&start={}"
headers = {"User-Agent": "Mozilla/5.0"}

# %%
all_jobs_list = []

for job_title in search_list:
    for page in range(0, 16):
        url = base_url.format(job_title.replace(" ", "%20"), page)
        print(f"Scraping for page {page}: {url}, the job title is : {job_title}")

        response = requests.get(url, headers = headers)
        soup = BeautifulSoup(response.content, 'lxml')

        titles = soup.find_all("h2", {'class': 'css-m604qf'})
        companies = soup.find_all('a', {'class': 'css-17s97q8'})
        occupations = soup.find_all('div', {'class': 'css-1lh32fc'})
        experiences = soup.find_all('div', {'class': 'css-y4udm8'})
        companies_locations = soup.find_all('span', {'class': 'css-5wys0k'})

        title_list = [title.text.strip() for title in titles]
        links_list = ["https://wuzzuf.net" + title.a['href'] for title in titles]
        companies_list = [company.text.replace(' -', '') for company in companies]
        occupation_list = [occupation.text[:9] + ' / ' + occupation.text[9:] for occupation in occupations]
        exp_list = [exp.text for exp in experiences]
        companies_locations_list = [loc.text for loc in companies_locations]

        for i in range(min(len(title_list), len(links_list), len(companies_list), len(occupation_list), len(exp_list), len(companies_locations_list))):
          job_data = {
              'Title': title_list[i],
              'Link': links_list[i],
              'Company': companies_list[i],
              'Company Location': companies_locations_list[i],
              'Occupation': occupation_list[i],
              'Experience': exp_list[i]
          }
          all_jobs_list.append(job_data)

        time.sleep(1)

data = pd.DataFrame(all_jobs_list)
data.to_csv("wuzzuf_scraped.csv", index=False)
# Out:
# Scraping for page 0: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=0, the job title is : Machine Learning Engineer
# Scraping for page 1: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=1, the job title is : Machine Learning Engineer
# Scraping for page 2: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=2, the job title is : Machine Learning Engineer
# Scraping for page 3: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=3, the job title is : Machine Learning Engineer
# Scraping for page 4: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=4, the job title is : Machine Learning Engineer
# Scraping for page 5: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=5, the job title is : Machine Learning Engineer
# Scraping for page 6: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=6, the job title is : Machine Learning Engineer
# Scraping for page 7: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=7, the job title is : Machine Learning Engineer
# Scraping for page 8: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=8, the job title is : Machine Learning Engineer
# Scraping for page 9: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=9, the job title is : Machine Learning Engineer
# Scraping for page 10: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=10, the job title is : Machine Learning Engineer
# Scraping for page 11: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=11, the job title is : Machine Learning Engineer
# Scraping for page 12: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=12, the job title is : Machine Learning Engineer
# Scraping for page 13: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=13, the job title is : Machine Learning Engineer
# Scraping for page 14: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=14, the job title is : Machine Learning Engineer
# Scraping for page 15: https://wuzzuf.net/search/jobs/?q=Machine%20Learning%20Engineer&a=hpb&start=15, the job title is : Machine Learning Engineer
# Scraping for page 0: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=0, the job title is : Data Analyst
# Scraping for page 1: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=1, the job title is : Data Analyst
# Scraping for page 2: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=2, the job title is : Data Analyst
# Scraping for page 3: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=3, the job title is : Data Analyst
# Scraping for page 4: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=4, the job title is : Data Analyst
# Scraping for page 5: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=5, the job title is : Data Analyst
# Scraping for page 6: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=6, the job title is : Data Analyst
# Scraping for page 7: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=7, the job title is : Data Analyst
# Scraping for page 8: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=8, the job title is : Data Analyst
# Scraping for page 9: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=9, the job title is : Data Analyst
# Scraping for page 10: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=10, the job title is : Data Analyst
# Scraping for page 11: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=11, the job title is : Data Analyst
# Scraping for page 12: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=12, the job title is : Data Analyst
# Scraping for page 13: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=13, the job title is : Data Analyst
# Scraping for page 14: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=14, the job title is : Data Analyst
# Scraping for page 15: https://wuzzuf.net/search/jobs/?q=Data%20Analyst&a=hpb&start=15, the job title is : Data Analyst
# Scraping for page 0: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=0, the job title is : Data Scientist
# Scraping for page 1: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=1, the job title is : Data Scientist
# Scraping for page 2: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=2, the job title is : Data Scientist
# Scraping for page 3: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=3, the job title is : Data Scientist
# Scraping for page 4: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=4, the job title is : Data Scientist
# Scraping for page 5: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=5, the job title is : Data Scientist
# Scraping for page 6: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=6, the job title is : Data Scientist
# Scraping for page 7: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=7, the job title is : Data Scientist
# Scraping for page 8: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=8, the job title is : Data Scientist
# Scraping for page 9: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=9, the job title is : Data Scientist
# Scraping for page 10: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=10, the job title is : Data Scientist
# Scraping for page 11: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=11, the job title is : Data Scientist
# Scraping for page 12: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=12, the job title is : Data Scientist
# Scraping for page 13: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=13, the job title is : Data Scientist
# Scraping for page 14: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=14, the job title is : Data Scientist
# Scraping for page 15: https://wuzzuf.net/search/jobs/?q=Data%20Scientist&a=hpb&start=15, the job title is : Data Scientist
# Scraping for page 0: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=0, the job title is : Business Intelligence
# Scraping for page 1: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=1, the job title is : Business Intelligence
# Scraping for page 2: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=2, the job title is : Business Intelligence
# Scraping for page 3: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=3, the job title is : Business Intelligence
# Scraping for page 4: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=4, the job title is : Business Intelligence
# Scraping for page 5: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=5, the job title is : Business Intelligence
# Scraping for page 6: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=6, the job title is : Business Intelligence
# Scraping for page 7: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=7, the job title is : Business Intelligence
# Scraping for page 8: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=8, the job title is : Business Intelligence
# Scraping for page 9: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=9, the job title is : Business Intelligence
# Scraping for page 10: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=10, the job title is : Business Intelligence
# Scraping for page 11: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=11, the job title is : Business Intelligence
# Scraping for page 12: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=12, the job title is : Business Intelligence
# Scraping for page 13: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=13, the job title is : Business Intelligence
# Scraping for page 14: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=14, the job title is : Business Intelligence
# Scraping for page 15: https://wuzzuf.net/search/jobs/?q=Business%20Intelligence&a=hpb&start=15, the job title is : Business Intelligence

# %%
data
# Out:
#                                                  Title  \
# 0    Graduate Internship: Enterprise Software Engin...
# 1                                          AI Engineer
# 2                                       Data Scientist
# 3    AI Engineer (Computer Vision, Speech, NLP & Ge...
# 4                                       Data Scientist
# ..                                                 ...
# 330                                     Sales Engineer
# 331           Medical Sales Representative - Mohndseen
# 332                                     Sales Engineer
# 333                     Value, Access and Pricing Lead
# 334                 Project Technical Delivery Manager
#
#                                                   Link  \
# 0    https://wuzzuf.nethttps://wuzzuf.net/internshi...
# 1    https://wuzzuf.nethttps://wuzzuf.net/jobs/p/qg...
# 2    https://wuzzuf.nethttps://wuzzuf.net/jobs/p/bu...
# 3    https://wuzzuf.nethttps://wuzzuf.net/jobs/p/go...
# 4    https://wuzzuf.nethttps://wuzzuf.net/jobs/p/8o...
# ..                                                 ...
# 330  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/z9...
# 331  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/1b...
# 332  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/zt...
# 333  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/...
# 334  https://wuzzuf.nethttps://wuzzuf.net/jobs/p/g/...
#
#                                  Company              Company Location  \
# 0    eT3 Tomorrow Information Technology      New Cairo, Cairo, Egypt
# 1                        ProVision Group          Maadi, Cairo, Egypt
# 2                                  Lumin    Sheikh Zayed, Giza, Egypt
# 3                             Madar Soft   Fleming, Alexandria, Egypt
# 4                              Egabi FSI       Sheraton, Cairo, Egypt
# ..                                   ...                           ...
# 330  Electric House (lighting solutions)      Nasr City, Cairo, Egypt
# 331                    Alfa Laboratories     Mohandessin, Giza, Egypt
# 332                      bagnodesignmisr      New Cairo, Cairo, Egypt
# 333                               Sanofi         Riyadh, Saudi Arabia
# 334                               NVIDIA  Dubai, United Arab Emirates
#
#                                          Occupation  \
# 0                               Internshi / pHybrid
# 1    Full Time / Part TimeFreelance / ProjectHybrid
# 2                                Full Time / Hybrid
# 3                                Full Time / Remote
# 4                               Full Time / On-site
# ..                                              ...
# 330                              Full Time / Hybrid
# 331                             Full Time / On-site
# 332                             Full Time / On-site
# 333                                    Full Time /
# 334                                    Full Time /
#
#                                             Experience
# 0    InternshipHybridEntry Level · IT/Software Deve...
# 1    Full TimePart TimeFreelance / ProjectHybridExp...
# 2    Full TimeHybridExperienced · 3+ Yrs of Exp · I...
# 3    Full TimeRemoteExperienced · 3 - 5 Yrs of Exp ...
# 4    Full TimeOn-siteEntry Level · 1 - 4 Yrs of Exp...
# ..                                                 ...
# 330  Full TimeHybridEntry Level · 0 - 2 Yrs of Exp ...
# 331  Full TimeOn-siteEntry Level · 0 - 3 Yrs of Exp...
# 332  Full TimeOn-siteEntry Level · 0 - 1 Yrs of Exp...
# 333  Full TimeExperienced · Customer Service/Suppor...
# 334  Full TimeExperienced · IT/Software Development...
#
# [335 rows x 6 columns]
